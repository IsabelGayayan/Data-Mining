# %% [markdown]
# <a href="https://colab.research.google.com/github/IsabelGayayan/Data-Mining/blob/main/Web_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Web Scraper Project**
#
# I.
# Successfully scrape COVID-19 statistics from
# https://www.worldometers.info/coronavirus/#countriesLinks
#
# Ensure that all relevant data is scraped from the website without any errors or issues.
#
# Extract relevant data (countries, total_cases, new_cases, total_deaths, new_deaths, total_recovered, active_cases, critical)
#
# Ensure that all relevant data is accurately extracted, and there are no missing or incorrect values.
#
# Create a CSV file in the specified format
#
# Ensure that the CSV file contains all relevant data in the specified format and is easy to read and understand.
#
# II. Data Visualization
#
# Total Cases by Country:
# Create a visualization that accurately displays the total number of cases by country.
#
# Choropleth map: This visualization method should be used to display the data on a world map, where each country is shaded according to the number of cases. This allows for easy and quick comparisons between different countries
#
# Ensure that the choropleth map accurately displays the data, and it is easy to read and understand.
#
# Choose an appropriate color scale for the data being displayed and ensure that it is easy to interpret.
# Properly label the countries and provide a legend that explains the color scale and any other important information.
#
# Consider adding additional layers or markers to the map to provide more information or context.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 

link = "https://www.worldometers.info/coronavirus/#countries"

response = requests.get(link)
soup = BeautifulSoup(response.text, "html.parser")

table = soup.find("table", id = "main_table_countries_today")

headers = []
for header in table.findAll("th"):
  headers.append(header.text.strip())

rows = []
for row in table.findAll("tr")[1:]:
  rowData = []
  for cell in row.findAll("td"):
    rowData.append(cell.text.strip())
  rows.append(rowData)

df = pd.DataFrame(rows, columns = headers)

#extract columns 
df = df[['Country,Other', 'TotalCases', 'NewCases', 'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical']]

#save data to csv
df.to_csv("covid19_statistics.csv", index = False)

df
# Out:
#      Country,Other   TotalCases NewCases TotalDeaths NewDeaths TotalRecovered  \
# 0    North America  126,037,716   +3,880   1,626,406       +29    121,743,356
# 1             Asia  216,130,243  +29,803   1,543,404       +65    200,263,721
# 2           Europe  248,468,147  +18,032   2,036,063       +60    244,256,362
# 3    South America   68,505,954     +505   1,353,823               66,437,004
# 4          Oceania   14,099,317               26,971               13,913,281
# ..             ...          ...      ...         ...       ...            ...
# 242         Total:   68,505,954     +505   1,353,823               66,437,004
# 243         Total:   14,099,317               26,971               13,913,281
# 244         Total:   12,817,434       +8     258,705               12,083,344
# 245         Total:          721                   15                      706
# 246         Total:  686,059,532  +52,228   6,845,387      +154    658,697,774
#
#     ActiveCases Serious,Critical
# 0     2,667,954            6,711
# 1    14,323,118           15,628
# 2     2,175,722            6,423
# 3       715,127           10,163
# 4       159,065               71
# ..          ...              ...
# 242     715,127           10,163
# 243     159,065               71
# 244     475,385              548
# 245           0                0
# 246  20,516,371           39,544
#
# [247 rows x 8 columns]

# %%
import pandas as pd
import plotly.express as px

# Load the COVID-19 data from the CSV file
df = pd.read_csv('covid19_statistics.csv')

# Create a choropleth map using Plotly Express
fig = px.choropleth(df, locations='Country,Other', locationmode='country names', color='TotalCases',
                    hover_name='Country,Other', range_color=[0, df['TotalCases'].max()],
                    color_continuous_scale='reds', title='Total COVID-19 Cases by Country')

# Add a color bar and set its title
fig.update_layout(coloraxis_colorbar=dict(title='Total Cases'))

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="02663ae7-a535-4e4c-b646-281436bbc4b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02663ae7-a535-4e4c-b646-281436bbc4b0")) {                    Plotly.newPlot(                        "02663ae7-a535-4e4c-b646-281436bbc4b0",                        [{"colorscale":[[0.0,"#636efa"],[1.0,"#636efa"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=126,037,716<br>Country,Other=%{location}<extra></extra>","hovertext":["North America","Total:"],"locationmode":"country names","locations":["North America","Total:"],"name":"126,037,716","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#EF553B"],[1.0,"#EF553B"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=216,130,243<br>Country,Other=%{location}<extra></extra>","hovertext":["Asia","Total:"],"locationmode":"country names","locations":["Asia","Total:"],"name":"216,130,243","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#00cc96"],[1.0,"#00cc96"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=248,468,147<br>Country,Other=%{location}<extra></extra>","hovertext":["Europe","Total:"],"locationmode":"country names","locations":["Europe","Total:"],"name":"248,468,147","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#ab63fa"],[1.0,"#ab63fa"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=68,505,954<br>Country,Other=%{location}<extra></extra>","hovertext":["South America","Total:"],"locationmode":"country names","locations":["South America","Total:"],"name":"68,505,954","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#FFA15A"],[1.0,"#FFA15A"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=14,099,317<br>Country,Other=%{location}<extra></extra>","hovertext":["Oceania","Total:"],"locationmode":"country names","locations":["Oceania","Total:"],"name":"14,099,317","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#19d3f3"],[1.0,"#19d3f3"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=12,817,434<br>Country,Other=%{location}<extra></extra>","hovertext":["Africa","Total:"],"locationmode":"country names","locations":["Africa","Total:"],"name":"12,817,434","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#FF6692"],[1.0,"#FF6692"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=721<br>Country,Other=%{location}<extra></extra>","hovertext":[null,"Total:"],"locationmode":"country names","locations":[null,"Total:"],"name":"721","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#B6E880"],[1.0,"#B6E880"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=686,059,532<br>Country,Other=%{location}<extra></extra>","hovertext":["World","Total:"],"locationmode":"country names","locations":["World","Total:"],"name":"686,059,532","showlegend":true,"showscale":false,"z":[1,1],"type":"choropleth"},{"colorscale":[[0.0,"#FF97FF"],[1.0,"#FF97FF"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=106,514,992<br>Country,Other=%{location}<extra></extra>","hovertext":["USA"],"locationmode":"country names","locations":["USA"],"name":"106,514,992","showlegend":true,"showscale":false,"z":[1],"type":"choropleth"},{"colorscale":[[0.0,"#FECB52"],[1.0,"#FECB52"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>TotalCases=44,857,992<br>Country,Other=%{location}<extra></extra>","hovertext":["India"],"locationmode":"country names","locations":["India"],"name":"44,857,992","showlegend":true,"show ...
